# %% [markdown]
# ###### Installing Pandas
# from Command prompt run following command
# >pip install pandas

# %%
import os
import sys
print(os.path.dirname(sys.executable))
# Out:
# c:\users\halston\appdata\local\programs\python\python38-32

# %%
import pandas

# %%
df1 = pandas.DataFrame([[2,4,6],[4,16,36]])
df1
# Out:
#    0   1   2
# 0  2   4   6
# 1  4  16  36

# %% [markdown]
# # you can also pass another two parameters that defines Row Indexes and column names

# %%
df1 = pandas.DataFrame([[2,4,6],[4,16,36]],["Number","Square"],["Num 1","Num 2","Num 3"])
df1
# Out:
#         Num 1  Num 2  Num 3
# Number      2      4      6
# Square      4     16     36

# %% [markdown]
# # You can define Columns and Row Indexes with 'columns' & 'index' parameters

# %%
df2 = pandas.DataFrame([[2,4,6],[4,16,36]],columns=["Num 1","Num 2","Num 3"],index=["Number","Square"])
df2
# Out:
#         Num 1  Num 2  Num 3
# Number      2      4      6
# Square      4     16     36

# %% [markdown]
# # You Can also pass the "Disctionary" to DataFrame

# %%
df3 = pandas.DataFrame([{"Name":"Pramod","Surnam":"Ugale"},{"Name":"Jeffin"}])
df3
# Out:
#      Name Surnam
# 0  Pramod  Ugale
# 1  Jeffin    NaN

# %%
df1.mean()
# Out:
# Num 1     3.0
# Num 2    10.0
# Num 3    21.0
# dtype: float64

# %%
type(df1.mean())
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Series are nothing but dictionaries

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'LearningNumpy.ipynb',
#  'LearningPandas.ipynb',
#  'MyPythonLearning.ipynb',
#  'Newsmallgray.png',
#  'PandasApplications.ipynb',
#  'smallgray.png',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets_semi_colon.csv']

# %%
type(os.listdir())
# Out:
# list

# %%
df_json = pandas.read_json("supermarkets.json")
df_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_json.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_json.shape
# Out:
# (6, 7)

# %%
pandas.read_json?

# %%
df_csv = pandas.read_csv("http://pythonhow.com/supermarkets.csv")
df_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_csv_1 = pandas.read_csv("supermarkets_semi_colon.csv")
df_csv_1
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df_csv_1 = pandas.read_csv("supermarkets_semi_colon.csv",delimiter=';')
df_csv_1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# # Manipulating Data Frames

# %%
df_json
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_json = df_json.set_index("ID")
df_json
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_json.loc[3:5,"City"]
# Out:
# ID
# 3    San Francisco
# 4    San Francisco
# 5    San Francisco
# Name: City, dtype: object

# %%
names = df_json.loc[:,"Name"]
names
# Out:
# ID
# 1        Madeira
# 2    Bready Shop
# 3    Super River
# 4     Ben's Shop
# 5        Sanchez
# 6     Richvalley
# Name: Name, dtype: object

# %%
type(names)
# Out:
# pandas.core.series.Series

# %%
list(names)
# Out:
# ['Madeira',
#  'Bready Shop',
#  'Super River',
#  "Ben's Shop",
#  'Sanchez',
#  'Richvalley']

# %%
df_json
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_json.iloc[0,1]
# Out:
# 'San Francisco'

# %%
df_json.iloc[1:4,1:4]
# Out:
#              City             State Country
# ID
# 2   San Francisco          CA 94119     USA
# 3   San Francisco  California 94114     USA
# 4   San Francisco          CA 94114     USA

# %%
df_json
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_json.drop(2,axis=0)
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_json.columns
# Out:
# Index(['Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df_json.index
# Out:
# Int64Index([1, 2, 3, 4, 5, 6], dtype='int64', name='ID')

# %%
df_json.drop(df_json.columns[1:3],axis=1)
# Out:
#             Address Country         Name  Employees
# ID
# 1      3666 21st St     USA      Madeira          8
# 2    735 Dolores St     USA  Bready Shop         15
# 3       332 Hill St     USA  Super River         25
# 4      3995 23rd St     USA   Ben's Shop         10
# 5   1056 Sanchez St     USA      Sanchez         12
# 6   551 Alvarado St     USA   Richvalley         20

# %%
df_json.drop(df_json.index[2:4],axis=0)
# Out:
#             Address           City       State Country         Name  Employees
# ID
# 1      3666 21st St  San Francisco    CA 94114     USA      Madeira          8
# 2    735 Dolores St  San Francisco    CA 94119     USA  Bready Shop         15
# 5   1056 Sanchez St  San Francisco  California     USA      Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA   Richvalley         20

# %%
len(df_json.index)
# Out:
# 6

# %%
df_json.shape
# Out:
# (6, 6)

# %%
df_json.shape[0]
# Out:
# 6

# %%
df_json["Continent"]=df_json.shape[0] * ["North America"]

# %%
df_json
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees      Continent
# ID
# 1           8  North America
# 2          15  North America
# 3          25  North America
# 4          10  North America
# 5          12  North America
# 6          20  North America

# %%
df_json["Continent"] = df_json["Country"] + "," + "North America"

# %%
df_json
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees          Continent
# ID
# 1           8  USA,North America
# 2          15  USA,North America
# 3          25  USA,North America
# 4          10  USA,North America
# 5          12  USA,North America
# 6          20  USA,North America

# %% [markdown]
# # Adding New Row to Data Frame

# %%
df_json_t = df_json.T

# %%
df_json_t
# Out:
# ID                         1                  2                  3  \
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         4                  5                  6
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# Country                  USA                USA                USA
# Name              Ben's Shop            Sanchez         Richvalley
# Employees                 10                 12                 20
# Continent  USA,North America  USA,North America  USA,North America

# %%
df_json_t[7] = ["My Address","My City","My State","My Country","My Name",10,"My Continent"]

# %%
df_json_t
# Out:
# ID                         1                  2                  3  \
# Address         3666 21st St     735 Dolores St        332 Hill St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119   California 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop        Super River
# Employees                  8                 15                 25
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                         4                  5                  6  \
# Address         3995 23rd St    1056 Sanchez St    551 Alvarado St
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114         California           CA 94114
# Country                  USA                USA                USA
# Name              Ben's Shop            Sanchez         Richvalley
# Employees                 10                 12                 20
# Continent  USA,North America  USA,North America  USA,North America
#
# ID                    7
# Address      My Address
# City            My City
# State          My State
# Country      My Country
# Name            My Name
# Employees            10
# Continent  My Continent

# %%
df_json = df_json_t.T

# %%
df_json
# Out:
#             Address           City             State     Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114         USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119         USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114         USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114         USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California         USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114         USA   Richvalley
# 7        My Address        My City          My State  My Country      My Name
#
#    Employees          Continent
# ID
# 1          8  USA,North America
# 2         15  USA,North America
# 3         25  USA,North America
# 4         10  USA,North America
# 5         12  USA,North America
# 6         20  USA,North America
# 7         10       My Continent

# %%
df_json_t[1] = ["New Address","New City","New State","New Country","New Name",10,"New Continent"]

# %%
df_json = df_json_t.T

# %%
df_json
# Out:
#             Address           City             State      Country  \
# ID
# 1       New Address       New City         New State  New Country
# 2    735 Dolores St  San Francisco          CA 94119          USA
# 3       332 Hill St  San Francisco  California 94114          USA
# 4      3995 23rd St  San Francisco          CA 94114          USA
# 5   1056 Sanchez St  San Francisco        California          USA
# 6   551 Alvarado St  San Francisco          CA 94114          USA
# 7        My Address        My City          My State   My Country
#
#            Name Employees          Continent
# ID
# 1      New Name        10      New Continent
# 2   Bready Shop        15  USA,North America
# 3   Super River        25  USA,North America
# 4    Ben's Shop        10  USA,North America
# 5       Sanchez        12  USA,North America
# 6    Richvalley        20  USA,North America
# 7       My Name        10       My Continent
